# %%
a=int(input("Введите число "))
if a>1:
    print ("hello world")
if a == 6:
    print(a)
else:
    print(a*2)
# Out:
# Введите число 6
# hello world
# 6

# %%
a=5
b=int(input("Введите B "))
print (a*b)
# Out:
# Введите B 6
# 30

# %%
a=int(input("Введите A "))
b=int(input("Введите B "))

print ((a+b)**2)
# Out:
# Введите A 2
# Введите B 2
# 16

# %%
a=15
b=10
c=int(input("Введите C "))
print(a+b)
print ((a+b)/c)
# Out:
# Введите C 2
# 25
# 12.5

# %%
a=int(input("Введите A "))
b=int(input("Введите B "))

print ("(",a,"+",b,")^2=",(a+b)**2)
# Out:
# Введите A 2
# Введите B 2
# ( 2 + 2 )^2= 16

# %%
a=int(input("Введите a "))
b=int(input("Введите b "))
c=int(input("Введите c "))
p=1/2*(a+b+c)
print ("P=",a+b+c)
print ("S=",(p*(p-a)*(p-b)*(p-c)**0.5))
# Out:
# Введите a 2
# Введите b 4
# Введите c 5
# P= 11
# S= 20.41770830676156

# %%
a=int(input("Введите a "))
b=int(input("Введите b "))

print(((a**2+14)/5)*b)
# Out:
# Введите a 2
# Введите b 3
# 10.8

# %%
a=float(input("Введите a "))
b=float(input("Введите b "))

print ("1=", a//b)

c=int(input("Введите a "))
d=int(input("Введите b "))

print ("2=",c*d)
print ("3=",c%d)
# Out:
# Введите a 2.3
# Введите b 5.2
# 1= 0.0
# Введите a 5
# Введите b 3
# 2= 15
# 3= 2

# %%
sec=int(input("Введите секунды: "))

print(sec//86400, "Дней,", (sec%86400)//3600, "часов,", ((sec%86400)%3600)//60, ("минут"))
# Out:
# Введите секунды: 200000
# 2 Дней, 7 часов, 33 минут

# %%
n=int(input("Введите n"))

print("n+nn+nnn=", n+n**2+n**3)
# Out:
# Введите n2
# n+nn+nnn= 14
